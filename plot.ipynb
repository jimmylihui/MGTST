# %%
x=[96,192,336,720]
y1=[0.432,0.405,0.383,0.375]
y2=[0.293,0.290,0.281,0.273]
y3=[0.379,0.361,0.336,0.328]
y4=[0.394,0.365,0.328,0.326]
from matplotlib import pyplot as plt
plt.plot(x,y1,label='output length 720')
plt.plot(x,y2,label='output length 96')
plt.plot(x,y3,label='output length 192')
plt.plot(x,y4,label='output length 336')
plt.legend()
plt.xlabel('input length')
plt.ylabel('MSE')
plt.title('The effect of input length to MSE in ETTh1')
# Out:
# Text(0.5, 1.0, 'The effect of input length to MSE')

# %%
from matplotlib import pyplot as plt
fontsize=14
plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)
x=[32,64,128,256]
y1=[5.44,13.19,35.64,108.27]
y2=[2.27,5.52,14.91,45.33]
y3=[5.18,12.46,33.29,100.06]
y4=[2.22,5.37,14.45,43.69]
plt.plot(x,y1,'o-',label='MGTST' )
plt.plot(x,y2,'v-',label='MGTST without gate ')
plt.plot(x,y3,'s-',label='MGTST with multi-scale')
plt.plot(x,y4,'*-',label='MGTST without both')
plt.legend(loc='upper left',prop={'size':8})
plt.xlabel('hidden dimension D',fontsize=fontsize)
plt.ylabel('FLOPs (G)',fontsize=fontsize)
plt.rcParams['figure.figsize'] = (4.5, 3.5)
plt.rcParams['savefig.dpi'] = 600
plt.rcParams['figure.dpi'] = 600
plt.savefig('/ssddata/data/jiahuili/PatchTST/pic/input length.png')

# %%
from matplotlib import pyplot as plt
fontsize=14
plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)
x=[96,192,336,512,720]
y1=[0.170-0.170,0.166-0.170,0.164-0.170,0.162-0.170,0.163-0.170]
y2=[0.238-0.238,0.226-0.238,0.221-0.238,0.217-0.238,0.227-0.238]
y3=[0.297-0.297,0.279-0.297,0.278-0.297,0.265-0.297,0.283-0.297]
y4=[0.389-0.389,0.372-0.389,0.367-0.389,0.352-0.389,0.357-0.389]
plt.plot(x,y1,'o-',label='output length 96' )
plt.plot(x,y2,'v-',label='output length 192')
plt.plot(x,y3,'s-',label='output length 336')
plt.plot(x,y4,'*-',label='output length 720')
plt.legend(loc='lower left',prop={'size':8})
plt.xlabel('Input length (Lx)',fontsize=fontsize)
plt.ylabel('MSE difference',fontsize=fontsize)
plt.rcParams['figure.figsize'] = (4.5, 3.5)
plt.rcParams['savefig.dpi'] = 600
plt.rcParams['figure.dpi'] = 600
plt.savefig('/ssddata/data/jiahuili/PatchTST/pic/input length.png')

# %%
from matplotlib import pyplot as plt
fontsize=14
plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)
x=[4,8,12,16,32,64]
y1=[0.372-0.372,0.371-0.372,0.373-0.372,0.370-0.372,0.369-0.372,0.368-0.372]
y2=[0.426-0.426,0.417-0.426,0.417-0.426,0.416-0.426,0.421-0.426,0.420-0.426]
y3=[0.427-0.427,0.420-0.427,0.423-0.427,0.423-0.427,0.424-0.427,0.436-0.427]
y4=[0.436-0.436,0.436-0.436,0.452-0.436,0.452-0.436,0.459-0.436,0.467-0.436]
plt.plot(x,y1,'o-',label='output length 96' )
plt.plot(x,y2,'v-',label='output length 192')
plt.plot(x,y3,'s-',label='output length 336')
plt.plot(x,y4,'*-',label='output length 720')
plt.legend(loc='upper left',prop={'size':7})
plt.xlabel('Stride length (Lx)',fontsize=fontsize)
plt.ylabel('MSE difference',fontsize=fontsize)
plt.rcParams['figure.figsize'] = (4.5, 3.5)
plt.rcParams['savefig.dpi'] = 600
plt.rcParams['figure.dpi'] = 600
plt.savefig('/ssddata/data/jiahuili/PatchTST/pic/Stride length.png')

# %%
x=[1,2,3,4,5,10]
y1=[0.165-0.165,0.163-0.165,0.163-0.165,0.163-0.165,0.163-0.165,0.162-0.165]
y2=[0.219-0.219,0.218-0.219,0.218-0.219,0.219-0.219,0.217-0.219,0.221-0.219]
y3=[0.278-0.278,0.274-0.278,0.276-0.278,0.274-0.278,0.273-0.278,0.272-0.278]
y4=[0.367-0.367,0.364-0.367,0.363-0.367,0.365-0.367,0.350-0.367,0.352-0.367]
fontsize=14
plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)
plt.plot(x,y1,'o-',label='output length 96')
plt.plot(x,y2,'v-',label='output length 192')
plt.plot(x,y3,'s-',label='output length 336')
plt.plot(x,y4,'*-',label='output length 720')

plt.xlabel('Scale number (n)',fontsize=fontsize)
plt.ylabel('MSE difference',fontsize=fontsize)
plt.legend(loc='lower left',prop={'size':8})
plt.rcParams['figure.figsize'] = (4.5, 3.5)
plt.rcParams['savefig.dpi'] = 600
plt.rcParams['figure.dpi'] = 600
plt.savefig('/ssddata/data/jiahuili/PatchTST/pic/scale number.png')

# %%
x=[1,2,3,4,5,10]
y1=[0.165,0.163,0.163,0.163,0.163,0.162]
y2=[0.219,0.218,0.218,0.219,0.217,0.221]
y3=[0.278,0.274,0.276,0.274,0.273,0.272]
y4=[0.367,0.364,0.363,0.365,0.350,0.352]

plt.plot(x,y1,label='output length 96')
plt.plot(x,y2,label='output length 192')
plt.plot(x,y3,label='output length 336')
plt.plot(x,y4,label='output length 720')
plt.legend()
plt.xlabel('Scale number')
plt.ylabel('MSE')
plt.title('The effect of Scale number to MSE')
# Out:
# Text(0.5, 1.0, 'The effect of Scale number to MSE')
